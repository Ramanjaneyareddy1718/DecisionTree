# %%
import numpy as np
import pandas  as pd 
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv("winequality-red.csv")
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error,r2_score
from sklearn.preprocessing import LabelEncoder
from sklearn import tree

# %%
x=df[["fixed acidity","volatile acidity","citric acid","pH","alcohol"]]
y=df["quality"]

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
d=DecisionTreeRegressor(random_state=92)

# %%
d.fit(xtrain,ytrain)
# Out:
# DecisionTreeRegressor(random_state=92)

# %%
d.score(xtrain,ytrain)
# Out:
# 1.0

# %%
y_p=d.predict(xtest)

# %%
m=mean_squared_error(y_p,ytest)*100
m
# Out:
# 77.1875

# %%
r=r2_score(y_p,ytest)*100
r
# Out:
# 7.831521992630252

# %%
d.predict([[11.2,0.280,0.56,3.16,9.8]])
# Out:
# C:\Users\adull\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# array([6.])

# %%
plt.figure(figsize=(12,8))
tree.plot_tree(d,filled=True)
plt.show()
